# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import time
import requests
from config import weather_api_key
from datetime import datetime
from citipy import citipy

# %%
# Create a set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | areosa
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | imamoglu
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | kuytun
# Processing Record 7 of Set 1 | aviles
# Processing Record 8 of Set 1 | lagoa
# Processing Record 9 of Set 1 | praya
# Processing Record 10 of Set 1 | coquimbo
# Processing Record 11 of Set 1 | namatanai
# Processing Record 12 of Set 1 | lavrentiya
# Processing Record 13 of Set 1 | akure
# Processing Record 14 of Set 1 | tobolsk
# Processing Record 15 of Set 1 | iranduba
# Processing Record 16 of Set 1 | ponta do sol
# Processing Record 17 of Set 1 | minbu
# Processing Record 18 of Set 1 | maragogi
# Processing Record 19 of Set 1 | port elizabeth
# Processing Record 20 of Set 1 | sao filipe
# Processing Record 21 of Set 1 | ribeira grande
# Processing Record 22 of Set 1 | hobyo
# Processing Record 23 of Set 1 | benghazi
# Processing Record 24 of Set 1 | umba
# Processing Record 25 of Set 1 | jodar
# Processing Record 26 of Set 1 | abu kamal
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | nagothana
# Processing Record 29 of Set 1 | chuy
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | east london
# Processing Record 32 of Set 1 | dukat
# Processing Record 33 of Set 1 | dalvik
# Processing Record 34 of Set 1 | esperance
# Processing Record 35 of Set 1 | touros
# Processing Record 36 of Set 1 | kapaa
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | hobart
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | winnemucca
# Processing Record 42 of Set 1 | antofagasta
# Processing Record 43 of Set 1 | hambantota
# Processing Record 44 of Set 1 | torbay
# Processing Record 45 of Set 1 | baghdad
# Processing Record 46 of Set 1 | bengkulu
# Processing Record 47 of Set 1 | port hedland
# Processing Record 48 of Set 1 | san patricio
# Processing Record 49 of Set 1 | miri
# Processing Record 50 of Set 1 | mindelo
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | xiaoshan
# Processing Record 3 of Set 2 | hithadhoo
# Processing Record 4 of Set 2 | port blair
# Processing Record 5 of Set 2 | ahipara
# Processing Record 6 of Set 2 | kaitangata
# Processing Record 7 of Set 2 | pevek
# Processing Record 8 of Set 2 | bilma
# Processing Record 9 of Set 2 | ostrovnoy
# Processing Record 10 of Set 2 | mandalgovi
# Processing Record 11 of Set 2 | manaure
# Processing Record 12 of Set 2 | ishigaki
# Processing Record 13 of Set 2 | ajaccio
# Processing Record 14 of Set 2 | vila velha
# Processing Record 15 of Set 2 | lorengau
# Processing Record 16 of Set 2 | beldanga
# Processing Record 17 of Set 2 | bluff
# Processing Record 18 of Set 2 | saint-philippe
# Processing Record 19 of Set 2 | thompson
# Processing Record 20 of Set 2 | tuktoyaktuk
# Processing Record 21 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 22 of Set 2 | nizhniy kuranakh
# Processing Record 23 of Set 2 | sorland
# Processing Record 24 of Set 2 | kasongo-lunda
# Processing Record 25 of Set 2 | pueblo
# Processing Record 26 of Set 2 | iqaluit
# Processing Record 27 of Set 2 | mahebourg
# Processing Record 28 of Set 2 | prieska
# Processing Record 29 of Set 2 | fairbanks
# Processing Record 30 of Set 2 | atuona
# Processing Record 31 of Set 2 | avera
# Processing Record 32 of Set 2 | hilo
# Processing Record 33 of Set 2 | norman wells
# Processing Record 34 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 35 of Set 2 | saldanha
# Processing Record 36 of Set 2 | udaipura
# Processing Record 37 of Set 2 | uni
# Processing Record 38 of Set 2 | cidreira
# Processing Record 39 of Set 2 | los llanos de aridane
# Processing Record 40 of Set 2 | port lincoln
# Processing Record 41 of Set 2 | chokurdakh
# Processing Record 42 of Set 2 | sistranda
# Processing Record 43 of Set 2 | kutum
# Processing Record 44 of Set 2 | nome
# Processing Record 45 of Set 2 | hermanus
# Processing Record 46 of Set 2 | glasgow
# Processing Record 47 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 48 of Set 2 | slavgorod
# Processing Record 49 of Set 2 | san joaquin
# Processing Record 50 of Set 2 | rikitea
# Processing Record 1 of Set 3 | devonport
# Processing Record 2 of Set 3 | saint george
# Processing Record 3 of Set 3 | qaanaaq
# Processing Record 4 of Set 3 | buala
# Processing Record 5 of Set 3 | sur
# Processing Record 6 of Set 3 | khatanga
# Processing Record 7 of Set 3 | kuopio
# Processing Record 8 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 9 of Set 3 | cherskiy
# Processing Record 10 of Set 3 | tadine
# Processing Record 11 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 3 | vaini
# Processing Record 13 of Set 3 | najran
# Processing Record 14 of Set 3 | cabo san lucas
# Processing Record 15 of Set 3 | jambi
# Processing Record 16 of Set 3 | socorro
# Processing Record 17 of Set 3 | usinsk
# Processing Record 18 of Set 3 | zhuhai
# Processing Record 19 of Set 3 | mae ramat
# Processing Record 20 of Set 3 | tiksi
# Processing Record 21 of Set 3 | mazamari
# Processing Record 22 of Set 3 | leningradskiy
# Processing Record 23 of Set 3 | kandrian
# Processing Record 24 of Set 3 | petauke
# Processing Record 25 of Set 3 | pangnirtung
# Processing Record 26 of Set 3 | souillac
# Processing Record 27 of Set 3 | hurghada
# Processing Record 28 of Set 3 | yellowknife
# Processing Record 29 of Set 3 | harper
# Processing Record 30 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 3 | talnakh
# Processing Record 32 of Set 3 | chhaprauli
# Processing Record 33 of Set 3 | tasiilaq
# Processing Record 34 of Set 3 | ixtapa
# Processing Record 35 of Set 3 | narsaq
# Processing Record 36 of Set 3 | eltham
# Processing Record 37 of Set 3 | yulara
# Processing Record 38 of Set 3 | russell
# Processing Record 39 of Set 3 | puerto lempira
# Processing Record 40 of Set 3 | saint-augustin
# Processing Record 41 of Set 3 | gari
# Processing Record 42 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 3 | nikolskoye
# Processing Record 44 of Set 3 | castro
# Processing Record 45 of Set 3 | katherine
# Processing Record 46 of Set 3 | jackson
# Processing Record 47 of Set 3 | xichang
# Processing Record 48 of Set 3 | yumen
# Processing Record 49 of Set 3 | half moon bay
# Processing Record 50 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 1 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 2 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 4 | vanavara
# Processing Record 4 of Set 4 | ursulo galvan
# Processing Record 5 of Set 4 | baijiantan
# Processing Record 6 of Set 4 | jamestown
# Processing Record 7 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 8 of Set 4 | chattanooga
# Processing Record 9 of Set 4 | san ramon de la nueva oran
# Processing Record 10 of Set 4 | aykhal
# Processing Record 11 of Set 4 | butaritari
# Processing Record 12 of Set 4 | upernavik
# Processing Record 13 of Set 4 | kattivakkam
# Processing Record 14 of Set 4 | severo-kurilsk
# Processing Record 15 of Set 4 | mayo
# Processing Record 16 of Set 4 | marsh harbour
# Processing Record 17 of Set 4 | lasa
# Processing Record 18 of Set 4 | panjakent
# Processing Record 19 of Set 4 | lagos
# Processing Record 20 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 4 | camacha
# Processing Record 22 of Set 4 | sao joao da barra
# Processing Record 23 of Set 4 | victoria
# Processing Record 24 of Set 4 | kodiak
# Processing Record 25 of Set 4 | santa rosa del sur
# Processing Record 26 of Set 4 | bredasdorp
# Processing Record 27 of Set 4 | mahon
# Processing Record 28 of Set 4 | trabzon
# Processing Record 29 of Set 4 | raudeberg
# Processing Record 30 of Set 4 | sayyan
# Processing Record 31 of Set 4 | georgetown
# Processing Record 32 of Set 4 | provideniya
# Processing Record 33 of Set 4 | kanchanaburi
# Processing Record 34 of Set 4 | beyneu
# Processing Record 35 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 4 | huarmey
# Processing Record 37 of Set 4 | tahe
# Processing Record 38 of Set 4 | isangel
# Processing Record 39 of Set 4 | yirol
# City not found. Skipping...
# Processing Record 40 of Set 4 | atar
# Processing Record 41 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 4 | mildura
# Processing Record 43 of Set 4 | laguna
# Processing Record 44 of Set 4 | chilliwack
# Processing Record 45 of Set 4 | boddam
# Processing Record 46 of Set 4 | kualakapuas
# Processing Record 47 of Set 4 | geraldton
# Processing Record 48 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 4 | andevoranto
# City not found. Skipping...
# Processing Record 50 of Set 4 | te anau
# Processing Record 1 of Set 5 | barysh
# Processing Record 2 of Set 5 | kikwit
# Processing Record 3 of Set 5 | longyearbyen
# Processing Record 4 of Set 5 | severnoye
# Processing Record 5 of Set 5 | teya
# Processing Record 6 of Set 5 | barrow
# Processing Record 7 of Set 5 | faanui
# Processing Record 8 of Set 5 | tura
# Processing Record 9 of Set 5 | boundiali
# Processing Record 10 of Set 5 | mahajanga
# Processing Record 11 of Set 5 | mount gambier
# Processing Record 12 of Set 5 | codrington
# Processing Record 13 of Set 5 | athens
# Processing Record 14 of Set 5 | saskylakh
# Processing Record 15 of Set 5 | bethel
# Processing Record 16 of Set 5 | prince rupert
# Processing Record 17 of Set 5 | bad doberan
# Processing Record 18 of Set 5 | katobu
# Processing Record 19 of Set 5 | vao
# Processing Record 20 of Set 5 | beatrice
# Processing Record 21 of Set 5 | puerto ayora
# Processing Record 22 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 23 of Set 5 | bereda
# Processing Record 24 of Set 5 | new norfolk
# Processing Record 25 of Set 5 | tilichiki
# Processing Record 26 of Set 5 | ostroda
# Processing Record 27 of Set 5 | deputatskiy
# Processing Record 28 of Set 5 | asau
# Processing Record 29 of Set 5 | grand bank
# Processing Record 30 of Set 5 | porgera
# Processing Record 31 of Set 5 | umtata
# Processing Record 32 of Set 5 | carnarvon
# Processing Record 33 of Set 5 | amboasary
# Processing Record 34 of Set 5 | flin flon
# Processing Record 35 of Set 5 | henties bay
# Processing Record 36 of Set 5 | omsukchan
# Processing Record 37 of Set 5 | qaqortoq
# Processing Record 38 of Set 5 | buqayq
# City not found. Skipping...
# Processing Record 39 of Set 5 | brus laguna
# Processing Record 40 of Set 5 | forestville
# Processing Record 41 of Set 5 | cordeiropolis
# Processing Record 42 of Set 5 | sola
# Processing Record 43 of Set 5 | arman
# Processing Record 44 of Set 5 | kahului
# Processing Record 45 of Set 5 | karasjok
# Processing Record 46 of Set 5 | white rock
# Processing Record 47 of Set 5 | vastervik
# City not found. Skipping...
# Processing Record 48 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 49 of Set 5 | the valley
# Processing Record 50 of Set 5 | bambous virieux
# Processing Record 1 of Set 6 | klaksvik
# Processing Record 2 of Set 6 | luderitz
# Processing Record 3 of Set 6 | saint anthony
# Processing Record 4 of Set 6 | tuatapere
# Processing Record 5 of Set 6 | assiniboia
# Processing Record 6 of Set 6 | broome
# Processing Record 7 of Set 6 | angoche
# Processing Record 8 of Set 6 | katsuura
# Processing Record 9 of Set 6 | yerbogachen
# Processing Record 10 of Set 6 | da lat
# Processing Record 11 of Set 6 | lincoln
# Processing Record 12 of Set 6 | north bend
# Processing Record 13 of Set 6 | lebu
# Processing Record 14 of Set 6 | raga
# Processing Record 15 of Set 6 | portland
# Processing Record 16 of Set 6 | fort nelson
# Processing Record 17 of Set 6 | jarjis
# City not found. Skipping...
# Processing Record 18 of Set 6 | uzventis
# Processing Record 19 of Set 6 | carballo
# Processing Record 20 of Set 6 | itabira
# Processing Record 21 of Set 6 | reading
# Processing Record 22 of Set 6 | koubia
# Processing Record 23 of Set 6 | of
# City not found. Skipping...
# Processing Record 24 of Set 6 | gaya
# Processing Record 25 of Set 6 | soyo
# Processing Record 26 of Set 6 | coari
# Processing Record 27 of Set 6 | medina
# Processing Record 28 of Set 6 | nizwa
# Processing Record 29 of Set 6 | mendoza
# Processing Record 30 of Set 6 | san carlos de bariloche
# Processing Record 31 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 6 | lompoc
# Processing Record 33 of Set 6 | ilulissat
# Processing Record 34 of Set 6 | beringovskiy
# Processing Record 35 of Set 6 | morgan city
# Processing Record 36 of Set 6 | olga
# Processing Record 37 of Set 6 | rahimatpur
# Processing Record 38 of Set 6 | kushiro
# Processing Record 39 of Set 6 | romny
# Processing Record 40 of Set 6 | palmas de monte alto
# Processing Record 41 of Set 6 | ahuimanu
# Processing Record 42 of Set 6 | havelock
# Processing Record 43 of Set 6 | winneba
# Processing Record 44 of Set 6 | biak
# Processing Record 45 of Set 6 | narwar
# Processing Record 46 of Set 6 | namibe
# Processing Record 47 of Set 6 | alofi
# Processing Record 48 of Set 6 | betioky
# Processing Record 49 of Set 6 | sao jose da coroa grande
# Processing Record 50 of Set 6 | pangody
# Processing Record 1 of Set 7 | octeville
# Processing Record 2 of Set 7 | pisco
# Processing Record 3 of Set 7 | boone
# Processing Record 4 of Set 7 | akyab
# Processing Record 5 of Set 7 | sorab
# Processing Record 6 of Set 7 | burica
# City not found. Skipping...
# Processing Record 7 of Set 7 | vargashi
# Processing Record 8 of Set 7 | bonham
# Processing Record 9 of Set 7 | ancud
# Processing Record 10 of Set 7 | mar del plata
# Processing Record 11 of Set 7 | manado
# Processing Record 12 of Set 7 | quelimane
# Processing Record 13 of Set 7 | acarau
# Processing Record 14 of Set 7 | adre
# Processing Record 15 of Set 7 | khandyga
# Processing Record 16 of Set 7 | belmonte
# Processing Record 17 of Set 7 | nova gradiska
# Processing Record 18 of Set 7 | sedelnikovo
# City not found. Skipping...
# Processing Record 19 of Set 7 | dawlatabad
# Processing Record 20 of Set 7 | eloi mendes
# Processing Record 21 of Set 7 | vestmannaeyjar
# Processing Record 22 of Set 7 | arraial do cabo
# Processing Record 23 of Set 7 | porto novo
# Processing Record 24 of Set 7 | kropotkin
# Processing Record 25 of Set 7 | kupang
# Processing Record 26 of Set 7 | limbang
# Processing Record 27 of Set 7 | nagato
# Processing Record 28 of Set 7 | yaroslavskiy
# Processing Record 29 of Set 7 | haines junction
# Processing Record 30 of Set 7 | uinskoye
# Processing Record 31 of Set 7 | bac lieu
# Processing Record 32 of Set 7 | padang
# Processing Record 33 of Set 7 | mundgod
# Processing Record 34 of Set 7 | ventspils
# Processing Record 35 of Set 7 | tombouctou
# Processing Record 36 of Set 7 | tutoia
# Processing Record 37 of Set 7 | dikson
# Processing Record 38 of Set 7 | bathsheba
# Processing Record 39 of Set 7 | nagari
# Processing Record 40 of Set 7 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 41 of Set 7 | litovko
# Processing Record 42 of Set 7 | chernyshevskiy
# Processing Record 43 of Set 7 | hamilton
# Processing Record 44 of Set 7 | awjilah
# Processing Record 45 of Set 7 | omboue
# Processing Record 46 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 7 | verkhnevilyuysk
# Processing Record 48 of Set 7 | alekseyevsk
# Processing Record 49 of Set 7 | noumea
# Processing Record 50 of Set 7 | lourdes
# Processing Record 1 of Set 8 | jinchang
# Processing Record 2 of Set 8 | pahrump
# Processing Record 3 of Set 8 | coihaique
# Processing Record 4 of Set 8 | port keats
# Processing Record 5 of Set 8 | grindavik
# Processing Record 6 of Set 8 | marzuq
# Processing Record 7 of Set 8 | havre-saint-pierre
# Processing Record 8 of Set 8 | hovd
# Processing Record 9 of Set 8 | clyde river
# Processing Record 10 of Set 8 | birin
# Processing Record 11 of Set 8 | thinadhoo
# Processing Record 12 of Set 8 | tokat
# Processing Record 13 of Set 8 | nizhniy baskunchak
# Processing Record 14 of Set 8 | nouadhibou
# Processing Record 15 of Set 8 | felidhoo
# City not found. Skipping...
# Processing Record 16 of Set 8 | bambui
# Processing Record 17 of Set 8 | pedreiras
# Processing Record 18 of Set 8 | opuwo
# Processing Record 19 of Set 8 | okha
# Processing Record 20 of Set 8 | sharlyk
# Processing Record 21 of Set 8 | dzilam gonzalez
# Processing Record 22 of Set 8 | egvekinot
# Processing Record 23 of Set 8 | shingu
# Processing Record 24 of Set 8 | paamiut
# Processing Record 25 of Set 8 | bhag
# Processing Record 26 of Set 8 | meulaboh
# Processing Record 27 of Set 8 | sioux lookout
# Processing Record 28 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 8 | rolla
# Processing Record 30 of Set 8 | dien bien
# City not found. Skipping...
# Processing Record 31 of Set 8 | aswan
# Processing Record 32 of Set 8 | stornoway
# Processing Record 33 of Set 8 | muswellbrook
# Processing Record 34 of Set 8 | warrington
# Processing Record 35 of Set 8 | port macquarie
# Processing Record 36 of Set 8 | san pedro de uraba
# Processing Record 37 of Set 8 | priladozhskiy
# Processing Record 38 of Set 8 | sosnovo-ozerskoye
# Processing Record 39 of Set 8 | kununurra
# Processing Record 40 of Set 8 | cangucu
# Processing Record 41 of Set 8 | cutervo
# Processing Record 42 of Set 8 | qurayyat
# Processing Record 43 of Set 8 | roura
# Processing Record 44 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 45 of Set 8 | airai
# Processing Record 46 of Set 8 | hwange
# Processing Record 47 of Set 8 | scalloway
# City not found. Skipping...
# Processing Record 48 of Set 8 | iquique
# Processing Record 49 of Set 8 | kasempa
# Processing Record 50 of Set 8 | bandarbeyla
# Processing Record 1 of Set 9 | nanortalik
# Processing Record 2 of Set 9 | arkansas city
# Processing Record 3 of Set 9 | honiara
# Processing Record 4 of Set 9 | rosarito
# Processing Record 5 of Set 9 | jacmel
# Processing Record 6 of Set 9 | penarroya-pueblonuevo
# Processing Record 7 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 8 of Set 9 | whyalla
# Processing Record 9 of Set 9 | volchikha
# Processing Record 10 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 9 | neckargemund
# Processing Record 12 of Set 9 | jakar
# Processing Record 13 of Set 9 | nisia floresta
# Processing Record 14 of Set 9 | cayenne
# Processing Record 15 of Set 9 | kudahuvadhoo
# Processing Record 16 of Set 9 | urdzhar
# City not found. Skipping...
# Processing Record 17 of Set 9 | salalah
# Processing Record 18 of Set 9 | grootfontein
# Processing Record 19 of Set 9 | tongchuan
# Processing Record 20 of Set 9 | markova
# Processing Record 21 of Set 9 | sitka
# Processing Record 22 of Set 9 | puksoozero
# Processing Record 23 of Set 9 | yungkang
# City not found. Skipping...
# Processing Record 24 of Set 9 | herat
# Processing Record 25 of Set 9 | cockburn town
# Processing Record 26 of Set 9 | dubbo
# Processing Record 27 of Set 9 | talcahuano
# Processing Record 28 of Set 9 | papara
# Processing Record 29 of Set 9 | olinda
# Processing Record 30 of Set 9 | rodionovo-nesvetayskaya
# Processing Record 31 of Set 9 | tessalit
# Processing Record 32 of Set 9 | gerede
# Processing Record 33 of Set 9 | yellandu
# Processing Record 34 of Set 9 | belaya gora
# Processing Record 35 of Set 9 | birao
# Processing Record 36 of Set 9 | yining
# Processing Record 37 of Set 9 | balingen
# Processing Record 38 of Set 9 | yefremov
# Processing Record 39 of Set 9 | okhotsk
# Processing Record 40 of Set 9 | taoudenni
# Processing Record 41 of Set 9 | severo-yeniseyskiy
# Processing Record 42 of Set 9 | pando
# Processing Record 43 of Set 9 | rocha
# Processing Record 44 of Set 9 | hofn
# Processing Record 45 of Set 9 | college
# Processing Record 46 of Set 9 | koungou
# Processing Record 47 of Set 9 | cochrane
# Processing Record 48 of Set 9 | carutapera
# Processing Record 49 of Set 9 | kayes
# Processing Record 50 of Set 9 | ocean city
# Processing Record 1 of Set 10 | umm lajj
# Processing Record 2 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 10 | richards bay
# Processing Record 4 of Set 10 | sinop
# Processing Record 5 of Set 10 | khambhat
# Processing Record 6 of Set 10 | la palma
# Processing Record 7 of Set 10 | chimbote
# Processing Record 8 of Set 10 | andros town
# Processing Record 9 of Set 10 | sokoni
# Processing Record 10 of Set 10 | saint-pierre
# Processing Record 11 of Set 10 | buin
# Processing Record 12 of Set 10 | vaitape
# Processing Record 13 of Set 10 | muli
# Processing Record 14 of Set 10 | senno
# Processing Record 15 of Set 10 | orel-izumrud
# Processing Record 16 of Set 10 | bahia blanca
# Processing Record 17 of Set 10 | constitucion
# Processing Record 18 of Set 10 | kavieng
# Processing Record 19 of Set 10 | necochea
# Processing Record 20 of Set 10 | cairns
# Processing Record 21 of Set 10 | veraval
# Processing Record 22 of Set 10 | nelson bay
# Processing Record 23 of Set 10 | swellendam
# Processing Record 24 of Set 10 | zemio
# Processing Record 25 of Set 10 | ati
# Processing Record 26 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 10 | urumqi
# Processing Record 28 of Set 10 | elko
# Processing Record 29 of Set 10 | pangkalanbuun
# Processing Record 30 of Set 10 | melfi
# Processing Record 31 of Set 10 | husavik
# Processing Record 32 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 10 | vila franca do campo
# Processing Record 34 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 35 of Set 10 | taltal
# Processing Record 36 of Set 10 | falun
# Processing Record 37 of Set 10 | krasnoselkup
# Processing Record 38 of Set 10 | san andres
# Processing Record 39 of Set 10 | kloulklubed
# Processing Record 40 of Set 10 | anadyr
# Processing Record 41 of Set 10 | paita
# Processing Record 42 of Set 10 | sao felix do xingu
# Processing Record 43 of Set 10 | buraydah
# Processing Record 44 of Set 10 | quatre cocos
# Processing Record 45 of Set 10 | marsa matruh
# Processing Record 46 of Set 10 | manadhoo
# Processing Record 47 of Set 10 | mayumba
# Processing Record 48 of Set 10 | wewak
# Processing Record 49 of Set 10 | ogre
# Processing Record 50 of Set 10 | moindou
# Processing Record 1 of Set 11 | brae
# Processing Record 2 of Set 11 | tefe
# Processing Record 3 of Set 11 | celestun
# Processing Record 4 of Set 11 | takoradi
# Processing Record 5 of Set 11 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 6 of Set 11 | indiana
# Processing Record 7 of Set 11 | westport
# Processing Record 8 of Set 11 | salym
# Processing Record 9 of Set 11 | leh
# Processing Record 10 of Set 11 | hasaki
# Processing Record 11 of Set 11 | slawno
# Processing Record 12 of Set 11 | skibbereen
# Processing Record 13 of Set 11 | jumla
# Processing Record 14 of Set 11 | medak
# Processing Record 15 of Set 11 | ukiah
# Processing Record 16 of Set 11 | shenjiamen
# Processing Record 17 of Set 11 | seoul
# Processing Record 18 of Set 11 | darab
# Processing Record 19 of Set 11 | wanning
# Processing Record 20 of Set 11 | la romana
# Processing Record 21 of Set 11 | shouguang
# Processing Record 22 of Set 11 | jerez
# Processing Record 23 of Set 11 | olot
# Processing Record 24 of Set 11 | kotido
# Processing Record 25 of Set 11 | maneromango
# Processing Record 26 of Set 11 | uige
# Processing Record 27 of Set 11 | itarema
# Processing Record 28 of Set 11 | sorong
# Processing Record 29 of Set 11 | sharan
# Processing Record 30 of Set 11 | minsk
# Processing Record 31 of Set 11 | dingle
# Processing Record 32 of Set 11 | key west
# Processing Record 33 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 34 of Set 11 | bundaberg
# Processing Record 35 of Set 11 | alexandria
# Processing Record 36 of Set 11 | atherton
# Processing Record 37 of Set 11 | sunrise manor
# Processing Record 38 of Set 11 | port hardy
# Processing Record 39 of Set 11 | dongsheng
# Processing Record 40 of Set 11 | oksfjord
# Processing Record 41 of Set 11 | armeria
# Processing Record 42 of Set 11 | tonj
# Processing Record 43 of Set 11 | lata
# Processing Record 44 of Set 11 | isiro
# Processing Record 45 of Set 11 | oyama
# Processing Record 46 of Set 11 | shitanjing
# Processing Record 47 of Set 11 | sergeyevka
# Processing Record 48 of Set 11 | parrita
# Processing Record 49 of Set 11 | axim
# Processing Record 50 of Set 11 | macon
# Processing Record 1 of Set 12 | liverpool
# Processing Record 2 of Set 12 | dauphin
# Processing Record 3 of Set 12 | byron bay
# Processing Record 4 of Set 12 | swarzedz
# Processing Record 5 of Set 12 | strezhevoy
# Processing Record 6 of Set 12 | save
# Processing Record 7 of Set 12 | chaman
# Processing Record 8 of Set 12 | cozumel
# Processing Record 9 of Set 12 | pitimbu
# Processing Record 10 of Set 12 | villanueva de la serena
# Processing Record 11 of Set 12 | visnes
# Processing Record 12 of Set 12 | eyl
# Processing Record 13 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 14 of Set 12 | mantua
# Processing Record 15 of Set 12 | warsaw
# Processing Record 16 of Set 12 | tiarei
# Processing Record 17 of Set 12 | mpika
# Processing Record 18 of Set 12 | lethem
# Processing Record 19 of Set 12 | kautokeino
# Processing Record 20 of Set 12 | pacific grove
# Processing Record 21 of Set 12 | tubuala
# Processing Record 22 of Set 12 | plettenberg bay
# Processing Record 23 of Set 12 | teknaf
# Processing Record 24 of Set 12 | sovetskiy
# Processing Record 25 of Set 12 | bharatpur
# Processing Record 26 of Set 12 | itoman
# Processing Record 27 of Set 12 | ayorou
# Processing Record 28 of Set 12 | qiyang
# Processing Record 29 of Set 12 | shimoda
# Processing Record 30 of Set 12 | moisakula
# Processing Record 31 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 12 | tecoanapa
# Processing Record 33 of Set 12 | washington
# Processing Record 34 of Set 12 | obo
# Processing Record 35 of Set 12 | porec
# Processing Record 36 of Set 12 | wanlaweyn
# Processing Record 37 of Set 12 | mumford
# Processing Record 38 of Set 12 | merauke
# Processing Record 39 of Set 12 | novyy starodub
# Processing Record 40 of Set 12 | myitkyina
# Processing Record 41 of Set 12 | totness
# Processing Record 42 of Set 12 | peleduy
# Processing Record 43 of Set 12 | dayong
# Processing Record 44 of Set 12 | nuuk
# Processing Record 45 of Set 12 | suoyarvi
# Processing Record 46 of Set 12 | jiancheng
# Processing Record 47 of Set 12 | jundia
# Processing Record 48 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 49 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 50 of Set 12 | poya
# Processing Record 1 of Set 13 | isfana
# Processing Record 2 of Set 13 | kaduqli
# Processing Record 3 of Set 13 | moose factory
# Processing Record 4 of Set 13 | sinnamary
# Processing Record 5 of Set 13 | auki
# Processing Record 6 of Set 13 | deori khas
# Processing Record 7 of Set 13 | ouidah
# Processing Record 8 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 9 of Set 13 | nabire
# Processing Record 10 of Set 13 | korla
# Processing Record 11 of Set 13 | rupert
# Processing Record 12 of Set 13 | san cristobal
# Processing Record 13 of Set 13 | yanchukan
# City not found. Skipping...
# Processing Record 14 of Set 13 | spirit river
# Processing Record 15 of Set 13 | pokaran
# Processing Record 16 of Set 13 | guerrero negro
# Processing Record 17 of Set 13 | bolshaya glushitsa
# Processing Record 18 of Set 13 | san rafael
# Processing Record 19 of Set 13 | bad salzungen
# Processing Record 20 of Set 13 | conde
# Processing Record 21 of Set 13 | ambilobe
# Processing Record 22 of Set 13 | shubarkuduk
# Processing Record 23 of Set 13 | gizo
# Processing Record 24 of Set 13 | anloga
# Processing Record 25 of Set 13 | mongu
# Processing Record 26 of Set 13 | ust-ishim
# Processing Record 27 of Set 13 | maridi
# Processing Record 28 of Set 13 | kruisfontein
# Processing Record 29 of Set 13 | faya
# Processing Record 30 of Set 13 | san juan
# Processing Record 31 of Set 13 | klyuchi
# Processing Record 32 of Set 13 | maralal
# Processing Record 33 of Set 13 | am timan
# Processing Record 34 of Set 13 | eureka
# Processing Record 35 of Set 13 | turan
# Processing Record 36 of Set 13 | povenets
# Processing Record 37 of Set 13 | puerto escondido
# Processing Record 38 of Set 13 | le port
# Processing Record 39 of Set 13 | osoyoos
# Processing Record 40 of Set 13 | tazovskiy
# Processing Record 41 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 42 of Set 13 | vostok
# Processing Record 43 of Set 13 | nefteyugansk
# Processing Record 44 of Set 13 | hervey bay
# Processing Record 45 of Set 13 | sinazongwe
# Processing Record 46 of Set 13 | abay
# Processing Record 47 of Set 13 | jalu
# Processing Record 48 of Set 13 | brodina
# Processing Record 49 of Set 13 | mopti
# Processing Record 50 of Set 13 | alyangula
# Processing Record 1 of Set 14 | neiafu
# Processing Record 2 of Set 14 | kampot
# Processing Record 3 of Set 14 | truth or consequences
# Processing Record 4 of Set 14 | nizhniy tsasuchey
# Processing Record 5 of Set 14 | villa maria
# Processing Record 6 of Set 14 | sibay
# Processing Record 7 of Set 14 | bitung
# Processing Record 8 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 9 of Set 14 | caravelas
# Processing Record 10 of Set 14 | berlevag
# Processing Record 11 of Set 14 | qasigiannguit
# Processing Record 12 of Set 14 | san quintin
# Processing Record 13 of Set 14 | braganca
# Processing Record 14 of Set 14 | natitingou
# Processing Record 15 of Set 14 | cedar city
# Processing Record 16 of Set 14 | dakoro
# Processing Record 17 of Set 14 | dickinson
# Processing Record 18 of Set 14 | somanda
# Processing Record 19 of Set 14 | fereydun kenar
# Processing Record 20 of Set 14 | linqiong
# Processing Record 21 of Set 14 | kapit
# Processing Record 22 of Set 14 | gejiu
# Processing Record 23 of Set 14 | atambua
# Processing Record 24 of Set 14 | benidorm
# Processing Record 25 of Set 14 | vanimo
# Processing Record 26 of Set 14 | kidodi
# Processing Record 27 of Set 14 | zelenoborsk
# Processing Record 28 of Set 14 | beidao
# Processing Record 29 of Set 14 | mucurapo
# Processing Record 30 of Set 14 | nenjiang
# Processing Record 31 of Set 14 | kirakira
# Processing Record 32 of Set 14 | libertador general san martin
# Processing Record 33 of Set 14 | palamos
# Processing Record 34 of Set 14 | port arthur
# Processing Record 35 of Set 14 | marystown
# Processing Record 36 of Set 14 | libenge
# Processing Record 37 of Set 14 | uyuni
# Processing Record 38 of Set 14 | vysokogornyy
# Processing Record 39 of Set 14 | luanda
# Processing Record 40 of Set 14 | sobolevo
# Processing Record 41 of Set 14 | amahai
# Processing Record 42 of Set 14 | springdale
# Processing Record 43 of Set 14 | bolobo
# Processing Record 44 of Set 14 | saint-louis
# Processing Record 45 of Set 14 | koch bihar
# Processing Record 46 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 47 of Set 14 | lodja
# Processing Record 48 of Set 14 | skibotn
# Processing Record 49 of Set 14 | high level
# Processing Record 50 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 15 | turmalina
# Processing Record 2 of Set 15 | acari
# Processing Record 3 of Set 15 | alihe
# Processing Record 4 of Set 15 | kamsack
# Processing Record 5 of Set 15 | visby
# Processing Record 6 of Set 15 | san pedro
# Processing Record 7 of Set 15 | waipawa
# Processing Record 8 of Set 15 | evensk
# Processing Record 9 of Set 15 | rawson
# Processing Record 10 of Set 15 | barra
# Processing Record 11 of Set 15 | tevriz
# Processing Record 12 of Set 15 | havoysund
# Processing Record 13 of Set 15 | yarada
# Processing Record 14 of Set 15 | manosque
# Processing Record 15 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 16 of Set 15 | mundo nuevo
# Processing Record 17 of Set 15 | antalaha
# Processing Record 18 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 15 | sfantu gheorghe
# Processing Record 20 of Set 15 | nemuro
# Processing Record 21 of Set 15 | krasnystaw
# Processing Record 22 of Set 15 | lwowek slaski
# Processing Record 23 of Set 15 | odweyne
# Processing Record 24 of Set 15 | glenwood springs
# Processing Record 25 of Set 15 | huilong
# Processing Record 26 of Set 15 | nouakchott
# Processing Record 27 of Set 15 | fortuna
# Processing Record 28 of Set 15 | ayan
# Processing Record 29 of Set 15 | karlskoga
# Processing Record 30 of Set 15 | mairana
# Processing Record 31 of Set 15 | onega
# Processing Record 32 of Set 15 | mizdah
# Processing Record 33 of Set 15 | bubaque
# Processing Record 34 of Set 15 | aden
# Processing Record 35 of Set 15 | lieksa
# Processing Record 36 of Set 15 | carbonia
# Processing Record 37 of Set 15 | chapais
# Processing Record 38 of Set 15 | bria
# Processing Record 39 of Set 15 | lardos
# Processing Record 40 of Set 15 | fengrun
# Processing Record 41 of Set 15 | saint-francois
# Processing Record 42 of Set 15 | praia
# Processing Record 43 of Set 15 | khasan
# Processing Record 44 of Set 15 | adrar
# Processing Record 45 of Set 15 | severomuysk
# Processing Record 46 of Set 15 | ashcroft
# Processing Record 47 of Set 15 | garowe
# Processing Record 48 of Set 15 | bundu
# Processing Record 49 of Set 15 | sijunjung
# Processing Record 50 of Set 15 | viedma
# Processing Record 1 of Set 16 | jizan
# Processing Record 2 of Set 16 | camalu
# Processing Record 3 of Set 16 | aktau
# Processing Record 4 of Set 16 | nador
# Processing Record 5 of Set 16 | mayya
# Processing Record 6 of Set 16 | banjar
# Processing Record 7 of Set 16 | makakilo city
# Processing Record 8 of Set 16 | kongoussi
# Processing Record 9 of Set 16 | bestobe
# Processing Record 10 of Set 16 | barcelos
# Processing Record 11 of Set 16 | falealupo
# City not found. Skipping...
# Processing Record 12 of Set 16 | srednekolymsk
# Processing Record 13 of Set 16 | ternate
# Processing Record 14 of Set 16 | mount pleasant
# Processing Record 15 of Set 16 | moussoro
# Processing Record 16 of Set 16 | tursunzoda
# Processing Record 17 of Set 16 | vardo
# Processing Record 18 of Set 16 | pedernales
# Processing Record 19 of Set 16 | burayevo
# Processing Record 20 of Set 16 | oistins
# Processing Record 21 of Set 16 | rubizhne
# Processing Record 22 of Set 16 | ucluelet
# Processing Record 23 of Set 16 | namwala
# Processing Record 24 of Set 16 | halifax
# Processing Record 25 of Set 16 | inongo
# Processing Record 26 of Set 16 | cancun
# Processing Record 27 of Set 16 | kathu
# Processing Record 28 of Set 16 | jiaojiang
# Processing Record 29 of Set 16 | hami
# Processing Record 30 of Set 16 | santa maria del oro
# Processing Record 31 of Set 16 | qiongshan
# Processing Record 32 of Set 16 | santa cruz de la palma
# Processing Record 33 of Set 16 | gualeguaychu
# Processing Record 34 of Set 16 | paysandu
# Processing Record 35 of Set 16 | kavaratti
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#        City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Albany  42.6001  -73.9662     21.31        77          10        4.18
# 1    Areosa  41.7178   -8.8571     50.32        68          57        5.66
# 2    Avarua -21.2078 -159.7750     80.65        78          20        9.22
# 3  Imamoglu  37.2651   35.6572     35.31        56           0        3.78
# 4   Ushuaia -54.8000  -68.3000     60.46        67          40       14.97
# 5    Kuytun  54.3419  101.5036     16.25        88         100        2.59
# 6    Aviles  43.5547   -5.9248     48.76        73         100        3.00
# 7     Lagoa  39.0500  -27.9833     59.50        84           6       16.98
# 8     Praya  14.9215  -23.5087     68.54        83           0       10.36
# 9  Coquimbo -29.9533  -71.3436     64.13        82         100        4.61
#
#   Country Current Description
# 0      US           clear sky
# 1      PT       broken clouds
# 2      CK          few clouds
# 3      TR           clear sky
# 4      AR    scattered clouds
# 5      RU     overcast clouds
# 6      ES     overcast clouds
# 7      PT           clear sky
# 8      CV           clear sky
# 9      CL     overcast clouds

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")
